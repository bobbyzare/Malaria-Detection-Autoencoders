# %%
# Importing Necessary Liabraries

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,UpSampling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
# Defining Size of Our Input Images
size = 128

# %%
# Defining Image Generaters for Training, Testing And Also for Anomaly Images

# %%
# Defining Batch Size
batch_size = 64
datagen = ImageDataGenerator(rescale=1./255)

# %%
# Image Generator for Trainig Images

train_generator = datagen.flow_from_directory(directory=r"C:\Users\11090367\Downloads\cell_images\Uninfected_train",
                                              target_size=(size,size),
                                             batch_size=batch_size,
                                             class_mode='input')
# Out:
# Found 13558 images belonging to 1 classes.

# %%
# Image Generator for validation Images

validation_generator = datagen.flow_from_directory(directory=r"C:\Users\11090367\Downloads\cell_images\Uninfected_test",
                                              target_size=(size,size),
                                             batch_size=batch_size,
                                             class_mode='input')
# Out:
# Found 100 images belonging to 1 classes.

# %%
# Image Generator for Anomaly Images

anomaly_generator = datagen.flow_from_directory(directory=r"C:\Users\11090367\Downloads\cell_images\Parasitized",
                                              target_size=(size,size),
                                             batch_size=batch_size,
                                             class_mode='input')
# Out:
# Found 13907 images belonging to 1 classes.

# %%
# Defining Autoencoder

# %%
# Encoder

model = Sequential()
model.add( Conv2D(64,(3,3), activation='relu', padding='same', input_shape=(size,size,3) ))
model.add(MaxPooling2D((2,2), padding='same'))

model.add( Conv2D(32,(3,3), activation='relu', padding='same') )
model.add(MaxPooling2D((2,2), padding='same'))

model.add( Conv2D(16,(3,3), activation='relu', padding='same') )
model.add(MaxPooling2D((2,2), padding='same'))

model.add( Conv2D(8,(3,3), activation='relu', padding='same') )
model.add(MaxPooling2D((2,2), padding='same'))
# Out:
# C:\Users\11090367\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Decoder 

model.add( Conv2D(8,(3,3), activation='relu', padding='same') )
model.add(UpSampling2D((2,2)))

model.add( Conv2D(16,(3,3), activation='relu', padding='same') )
model.add(UpSampling2D((2,2)))

model.add( Conv2D(32,(3,3), activation='relu', padding='same') )
model.add(UpSampling2D((2,2)))

model.add( Conv2D(64,(3,3), activation='relu', padding='same') )
model.add(UpSampling2D((2,2)))

model.add(Conv2D(3,(3,3),activation='sigmoid', padding='same'))

# %%
# Model Compile

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse','accuracy'])

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 8)           │           1,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 8, 8, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 8)             │             584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 16, 16, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 16, 16, 16)          │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_2 (UpSampling2D)       │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_3 (UpSampling2D)       │ (None, 128, 128, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 128, 128, 3)         │           1,731 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 52,659 (205.70 KB)
#  Trainable params: 52,659 (205.70 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit The Model

history = model.fit(
        train_generator,
        epochs=10,
        validation_data=validation_generator, 
       )
# Out:
# Epoch 1/10
# C:\Users\11090367\AppData\Local\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.5562 - loss: 0.0342 - mse: 0.0342 - val_accuracy: 0.5402 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 2/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 220s 1s/step - accuracy: 0.5684 - loss: 0.0110 - mse: 0.0110 - val_accuracy: 0.6884 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 3/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 217s 1s/step - accuracy: 0.6926 - loss: 0.0089 - mse: 0.0089 - val_accuracy: 0.6697 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 4/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.6947 - loss: 0.0081 - mse: 0.0081 - val_accuracy: 0.6865 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 5/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.7070 - loss: 0.0076 - mse: 0.0076 - val_accuracy: 0.6894 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 6/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 217s 1s/step - accuracy: 0.7068 - loss: 0.0073 - mse: 0.0073 - val_accuracy: 0.6948 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 7/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 215s 1s/step - accuracy: 0.7029 - loss: 0.0070 - mse: 0.0070 - val_accuracy: 0.6780 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 8/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 217s 1s/step - accuracy: 0.7025 - loss: 0.0069 - mse: 0.0069 - val_accuracy: 0.6850 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 9/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.7011 - loss: 0.0067 - mse: 0.0067 - val_accuracy: 0.6799 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 10/10
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - accuracy: 0.7057 - loss: 0.0066 - mse: 0.0066 - val_accuracy: 0.6903 - val_loss: 0.0086 - val_mse: 0.0086

# %%
#plot the training and validation loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plot the training and validation mse at each epoch
mse = history.history['mse']
val_mse = history.history['val_mse']
epochs = range(1, len(mse) + 1)

plt.plot(epochs, mse, 'g', label='Training mse')
plt.plot(epochs, val_mse, 'r', label='Validation mse')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
#plot the training and validation mse at each epoch
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(mse) + 1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('mse')
plt.legend()
plt.show()

# %%
# Get all batches generated by the datagen and pick a batch for prediction
#Just to test the model. 
data_batch = []  #Capture all training batches as a numpy array
img_num = 0
while img_num <= train_generator.batch_index:   #gets each generated batch of size batch_size
    data = next(train_generator)
    data_batch.append(data[0])
    img_num = img_num + 1

print('Done1')
# Out:
# Done1

# %%
predicted = model.predict(data_batch[0])  #Predict on the first batch of images
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 324ms/step

# %%
# Sanity check

for i in range(0,10):
    number = [i for i in range(0,63)]
    image_number = random.choice(number)
    plt.figure(figsize=(12, 8))

    # Display the original image
    plt.subplot(1, 2, 1)  # (1 row, 2 columns, 1st subplot)
    plt.imshow(data_batch[0][image_number])
    plt.xlabel(f'Actual Image Number {image_number}')# Assuming data_batch[0] contains the images
    plt.title("Original Image")

    # Display the predicted image (or corresponding output)
    plt.subplot(1, 2, 2)  # (1 row, 2 columns, 2nd subplot)
    plt.imshow(predicted[image_number])
    plt.xlabel(f'Predicted Image Number {image_number}')
    plt.title("Predicted Image")

    # Show the plots
    plt.show()

# %%
#Let us examine the reconstruction error between our validation data (good/normal images)
# and the anomaly images
validation_error = model.evaluate(validation_generator)
anomaly_error = model.evaluate(anomaly_generator)

print("Recon. error for the validation (normal) data is: ", validation_error)
print("Recon. error for the anomaly data is: ", anomaly_error)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.6915 - loss: 0.0086 - mse: 0.0086
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 80s 368ms/step - accuracy: 0.7284 - loss: 0.0081 - mse: 0.0081
# Recon. error for the validation (normal) data is:  [0.008570817299187183, 0.008570817299187183, 0.6903222799301147]
# Recon. error for the anomaly data is:  [0.008111503906548023, 0.008111503906548023, 0.7290827035903931]

# %%
# for calculating kde or latency space

# %%
# Create a new model for the encoder
encoder_model = Sequential()

# Add the layers to the encoder model with pre-trained weights
encoder_model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(size, size, 3)))

encoder_model.add(MaxPooling2D((2, 2), padding='same'))

encoder_model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))

encoder_model.add(MaxPooling2D((2, 2), padding='same'))

encoder_model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))

encoder_model.add(MaxPooling2D((2, 2), padding='same'))

encoder_model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))

encoder_model.add(MaxPooling2D((2, 2), padding='same'))

# Summary of the encoder model to check the structure
encoder_model.summary()
# Out:
# C:\Users\11090367\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_74 (Conv2D)                   │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_51 (MaxPooling2D)      │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_75 (Conv2D)                   │ (None, 64, 64, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_52 (MaxPooling2D)      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_76 (Conv2D)                   │ (None, 32, 32, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_53 (MaxPooling2D)      │ (None, 16, 16, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_77 (Conv2D)                   │ (None, 16, 16, 8)           │           1,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_54 (MaxPooling2D)      │ (None, 8, 8, 8)             │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,040 (101.72 KB)
#  Trainable params: 26,040 (101.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Calculate KDE using sklearn
from sklearn.neighbors import KernelDensity

# %%
encoded_images = encoder_model.predict(train_generator)
# Out:
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 52s 236ms/step

# %%
encoder_output_shape = encoder_model.output_shape
print(encoder_output_shape)
encoder_output_shape = encoder_output_shape[1:]
print(encoder_output_shape)
# Out:
# (None, 8, 8, 8)
# (8, 8, 8)

# %%
one_vector_shape = encoder_output_shape[0]*encoder_output_shape[1]*encoder_output_shape[2]

# %%
encoded_images_vector = [np.reshape(img,(one_vector_shape))for img in encoded_images]

# %%
# Fit the kde to image data
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(encoded_images_vector)

# %%
def calc_density_and_reconstruction_error(batch_images):

    density_error = []
    reconstruction_error = []
    for im in range(0, batch_images.shape[0]-1):

        img  = batch_images[im]
        img = img[np.newaxis, :,:,:]
        encoded_img = encoder_model.predict([[img]]) # Create a compressed version of the image using the encoder
        encoded_img = [np.reshape(img, (one_vector_shape)) for img in encoded_img] # Flatten the compressed image
        density = kde.score_samples(encoded_img) # get a density score for the new image
        reconstruction = model.predict([[img]])
        reconstruction_error = model.evaluate(reconstruction)
        density_list.append(density)
        recon_error_list.append(reconstruction_error)
        
    average_density = np.mean(np.array(density_list))  
    stdev_density = np.std(np.array(density_list)) 
    
    average_recon_error = np.mean(np.array(recon_error_list))  
    stdev_recon_error = np.std(np.array(recon_error_list)) 
    
    return average_density, stdev_density, average_recon_error, stdev_recon_error

#Get average and std dev. of density and recon. error for uninfected and anomaly (parasited) images. 
#For this let us generate a batch of images for each. 
train_batch = next(train_generator)[0]
anomaly_batch = next(anomaly_generator)[0]

uninfected_values = calc_density_and_reconstruction_error(train_batch)
anomaly_values = calc_density_and_reconstruction_error(anomaly_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[159], line 30
#      27 train_batch = next(train_generator)[0]
#      28 anomaly_batch = next(anomaly_generator)[0]
# ---> 30 uninfected_values = calc_density_and_reconstruction_error(train_batch)
#      31 anomaly_values = calc_density_and_reconstruction_error(anomaly_batch)
#
# Cell In[159], line 13, in calc_density_and_reconstruction_error(batch_images)
#      11 density = kde.score_samples(encoded_img) # get a density score for the new image
#      12 reconstruction = model.predict([[img]])
# ---> 13 reconstruction_error = model.evaluate(reconstruction)
#      14 density_list.append(density)
#      15 recon_error_list.append(reconstruction_error)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\input_spec.py:227, in assert_input_compatibility(input_spec, inputs, layer_name)
#     222     for axis, value in spec.axes.items():
#     223         if value is not None and shape[axis] not in {
#     224             value,
#     225             None,
#     226         }:
# --> 227             raise ValueError(
#     228                 f'Input {input_index} of layer "{layer_name}" is '
#     229                 f"incompatible with the layer: expected axis {axis} "
#     230                 f"of input shape to have value {value}, "
#     231                 "but received input with "
#     232                 f"shape {shape}"
#     233             )
#     234 # Check shape.
#     235 if spec.shape is not None:
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Input 0 of layer "conv2d" is incompatible with the layer: expected axis -1 of input shape to have value 3, but received input with shape (None, 128, 128, 64)
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=(None, 128, 128, 64), dtype=float32)
#   • training=False
#   • mask=None
